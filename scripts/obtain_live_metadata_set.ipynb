# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/b1/67/aca1f6e215d957d24d0a290321f368503305480268f9617bf625243e9dea/pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/jack/projects/Animating-RDGs/.conda/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jack/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jack/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jack/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/jack/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 7.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pandas
# Successfully installed pandas-2.1.4

# %% [markdown]
# # From the Merged Metadata produce the final set in a csv that is to be loaded into DB

# %%
import pandas as pd

# %% [markdown]
# Load in the csv. This is the product of the metadata cleaning scripts. It has x, y and st variants of core columns.

# %%
csv_file = '../data/Cleaned_Metadata_Merged_w_Manual_x_y_st_metadata_merged_with_manual.csv'
csv_file = "../standardized_columns_final_2023-12-18.csv"

# %%
df = pd.read_csv(csv_file)
df.head()
# Out:
# /tmp/ipykernel_571797/2592454444.py:1: DtypeWarning: Columns (32,33,34,40,41,42,63,73,74,78,79,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
#          Run     spots       bases  avgLength  size_MB         LibraryName  \
# 0  DRR244662  50599092  3845530992       76.0     1273  Ribosome profiling
# 1  DRR244663  50768935  3858439060       76.0     1269  Ribosome profiling
# 2  DRR255640  53029459  1837645023       34.0      792                 NaN
# 3  DRR255641  60864576  2145161510       35.0      874                 NaN
# 4  DRR255642  55434616  1923586815       34.0      828                 NaN
#
#   LibraryStrategy    LibrarySelection   LibrarySource LibraryLayout  ...  \
# 0         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 1         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 2         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 3         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 4         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
#
#    INHIBITOR_st  TIMEPOINT_st FRACTION_st REPLICATE_st CONDITION_st  \
# 0           NaN           NaN         NaN          1.0          NaN
# 1           NaN           NaN         NaN          2.0          NaN
# 2           NaN           NaN         NaN          1.0           WT
# 3           NaN           NaN         NaN          2.0           WT
# 4           NaN           NaN         NaN          1.0          NaN
#
#   LIBRARYTYPE_st      Run.1 BioProject.1                 name not_unique
# 0            RFP  DRR244662   PRJDB10544          _____1__RFP      False
# 1            RFP  DRR244663   PRJDB10544  S2_embryo____2__RFP      False
# 2            RFP  DRR255640   PRJDB10799        _____1_WT_RFP      False
# 3            RFP  DRR255641   PRJDB10799        _____2_WT_RFP      False
# 4            RFP  DRR255642   PRJDB10799          _____1__RFP      False
#
# [5 rows x 97 columns]

# %% [markdown]
# Write these values into a df with all columns (including those from SRA)

# %%
full_df = pd.read_csv(csv_file)
full_df.head()
# Out:
# /tmp/ipykernel_571797/55852251.py:1: DtypeWarning: Columns (32,33,34,40,41,42,63,73,74,78,79,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df = pd.read_csv(csv_file)
#          Run     spots       bases  avgLength  size_MB         LibraryName  \
# 0  DRR244662  50599092  3845530992       76.0     1273  Ribosome profiling
# 1  DRR244663  50768935  3858439060       76.0     1269  Ribosome profiling
# 2  DRR255640  53029459  1837645023       34.0      792                 NaN
# 3  DRR255641  60864576  2145161510       35.0      874                 NaN
# 4  DRR255642  55434616  1923586815       34.0      828                 NaN
#
#   LibraryStrategy    LibrarySelection   LibrarySource LibraryLayout  ...  \
# 0         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 1         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 2         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 3         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 4         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
#
#    INHIBITOR_st  TIMEPOINT_st FRACTION_st REPLICATE_st CONDITION_st  \
# 0           NaN           NaN         NaN          1.0          NaN
# 1           NaN           NaN         NaN          2.0          NaN
# 2           NaN           NaN         NaN          1.0           WT
# 3           NaN           NaN         NaN          2.0           WT
# 4           NaN           NaN         NaN          1.0          NaN
#
#   LIBRARYTYPE_st      Run.1 BioProject.1                 name not_unique
# 0            RFP  DRR244662   PRJDB10544          _____1__RFP      False
# 1            RFP  DRR244663   PRJDB10544  S2_embryo____2__RFP      False
# 2            RFP  DRR255640   PRJDB10799        _____1_WT_RFP      False
# 3            RFP  DRR255641   PRJDB10799        _____2_WT_RFP      False
# 4            RFP  DRR255642   PRJDB10799          _____1__RFP      False
#
# [5 rows x 97 columns]

# %%
update_columns = [col for col in full_df.columns if col.endswith("_st")]

for col in update_columns:
    base_col = col[:-3]
    full_df[base_col] = df[col]
full_df.head()
# Out:
#          Run     spots       bases  avgLength  size_MB         LibraryName  \
# 0  DRR244662  50599092  3845530992       76.0     1273  Ribosome profiling
# 1  DRR244663  50768935  3858439060       76.0     1269  Ribosome profiling
# 2  DRR255640  53029459  1837645023       34.0      792                 NaN
# 3  DRR255641  60864576  2145161510       35.0      874                 NaN
# 4  DRR255642  55434616  1923586815       34.0      828                 NaN
#
#   LibraryStrategy    LibrarySelection   LibrarySource LibraryLayout  ...  \
# 0         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 1         RNA-Seq              RANDOM  TRANSCRIPTOMIC        SINGLE  ...
# 2         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 3         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
# 4         RNA-Seq  size fractionation  TRANSCRIPTOMIC        SINGLE  ...
#
#    INHIBITOR_st  TIMEPOINT_st FRACTION_st REPLICATE_st CONDITION_st  \
# 0           NaN           NaN         NaN          1.0          NaN
# 1           NaN           NaN         NaN          2.0          NaN
# 2           NaN           NaN         NaN          1.0           WT
# 3           NaN           NaN         NaN          2.0           WT
# 4           NaN           NaN         NaN          1.0          NaN
#
#   LIBRARYTYPE_st      Run.1 BioProject.1                 name not_unique
# 0            RFP  DRR244662   PRJDB10544          _____1__RFP      False
# 1            RFP  DRR244663   PRJDB10544  S2_embryo____2__RFP      False
# 2            RFP  DRR255640   PRJDB10799        _____1_WT_RFP      False
# 3            RFP  DRR255641   PRJDB10799        _____2_WT_RFP      False
# 4            RFP  DRR255642   PRJDB10799          _____1__RFP      False
#
# [5 rows x 97 columns]

# %% [markdown]
# write the df to file

# %%
full_df.drop(columns=["name", 'not_unique', 'Run.1', 'BioProject.1'], inplace=True)
full_df.drop(columns=update_columns, inplace=True)

# %%
full_df
# Out:
#                Run     spots       bases  avgLength  size_MB  \
# 0        DRR244662  50599092  3845530992       76.0     1273
# 1        DRR244663  50768935  3858439060       76.0     1269
# 2        DRR255640  53029459  1837645023       34.0      792
# 3        DRR255641  60864576  2145161510       35.0      874
# 4        DRR255642  55434616  1923586815       34.0      828
# ...            ...       ...         ...        ...      ...
# 12274  SRR16249181  72669411  3633470550       50.0     1924
# 12275  SRR16249184  64471307  3223565350       50.0      960
# 12276  SRR16249185  50744643  2537232150       50.0      757
# 12277  SRR16249188  80312239  4015611950       50.0     2108
# 12278  SRR16249189  49669299  2483464950       50.0     1334
#
#               LibraryName LibraryStrategy    LibrarySelection   LibrarySource  \
# 0      Ribosome profiling         RNA-Seq              RANDOM  TRANSCRIPTOMIC
# 1      Ribosome profiling         RNA-Seq              RANDOM  TRANSCRIPTOMIC
# 2                     NaN         RNA-Seq  size fractionation  TRANSCRIPTOMIC
# 3                     NaN         RNA-Seq  size fractionation  TRANSCRIPTOMIC
# 4                     NaN         RNA-Seq  size fractionation  TRANSCRIPTOMIC
# ...                   ...             ...                 ...             ...
# 12274                 NaN           OTHER               other  TRANSCRIPTOMIC
# 12275                 NaN           OTHER               other  TRANSCRIPTOMIC
# 12276                 NaN           OTHER               other  TRANSCRIPTOMIC
# 12277                 NaN           OTHER               other  TRANSCRIPTOMIC
# 12278                 NaN           OTHER               other  TRANSCRIPTOMIC
#
#       LibraryLayout  ...  Stimulation  Host  UMI Adapter Separation  \
# 0            SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 1            SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 2            SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 3            SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 4            SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# ...             ...  ...          ...   ...  ...     ...        ...
# 12274        SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 12275        SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 12276        SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 12277        SINGLE  ...          NaN   NaN  NaN     NaN        NaN
# 12278        SINGLE  ...          NaN   NaN  NaN     NaN        NaN
#
#       rRNA_depletion  Barcode Nuclease  Kit  \
# 0                NaN      NaN      NaN  NaN
# 1                NaN      NaN      NaN  NaN
# 2                NaN      NaN      NaN  NaN
# 3                NaN      NaN      NaN  NaN
# 4                NaN      NaN      NaN  NaN
# ...              ...      ...      ...  ...
# 12274            NaN      NaN      NaN  NaN
# 12275            NaN      NaN      NaN  NaN
# 12276            NaN      NaN      NaN  NaN
# 12277            NaN      NaN      NaN  NaN
# 12278            NaN      NaN      NaN  NaN
#
#                                            Info
# 0                         AT01_NoTrim_S1_R1_001
# 1                         AT02_NoTrim_S2_R1_001
# 2          Ribo-seq_WT_rep1_Ribosome footprints
# 3          Ribo-seq_WT_rep2_Ribosome footprints
# 4      Ribo-seq_pgr3-1_rep1_Ribosome footprints
# ...                                         ...
# 12274               secA∆ZnBD total translatome
# 12275                   ∆secB total translatome
# 12276                   ∆secB total translatome
# 12277                WT total translatome, CCCP
# 12278                WT total translatome, CCCP
#
# [12279 rows x 85 columns]

# %%
from datetime import datetime
today_date = datetime.today().strftime('%Y-%m-%d')
file_name = f'../data/Cleaned_Metadata_For_Upload_{today_date}.csv'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 import datetime
# ----> 2 today_date = datetime.today().strftime('%Y-%m-%d')
#       3 file_name = f'../data/Cleaned_Metadata_For_Upload_{today_date}.csv'
#
# AttributeError: module 'datetime' has no attribute 'today'
